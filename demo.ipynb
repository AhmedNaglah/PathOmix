# %%
import subprocess

subprocess.run(["/blue/pinaki.sarder/ahmed.naglah/conda/envs/mofa2_env/bin/Rscript", "runMOFA.R"], check=True)
# Out:
# Warning message:
# In readLines(file, warn = readLines.warn) :
#   incomplete final line found on 'config.yml'
#
# Attaching package: ‘MOFA2’
#
# The following object is masked from ‘package:stats’:
#
#     predict
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ✔ Environment configured.
# python:         /blue/pinaki.sarder/ahmed.naglah/conda/envs/mofa2_env/bin/python3
# libpython:      /blue/pinaki.sarder/ahmed.naglah/conda/envs/mofa2_env/lib/libpython3.10.so
# ...
